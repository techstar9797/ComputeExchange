# %% [markdown]
# # ComputeExchange – Training in Colab (HF TRL / Unsloth)
#
# Minimal training script for **reward curves** and **TRL-based training**. See [COLAB_TRAINING.md](https://github.com/techstar9797/ComputeExchange/blob/main/scripts/COLAB_TRAINING.md) for full instructions.
#
# **Run the two cells below.** Optional: use [Unsloth](https://github.com/unslothai/unsloth) for 4-bit training (see COLAB_TRAINING.md).

# %%
# Cell 1: Clone repo and install dependencies
# !git clone https://github.com/techstar9797/ComputeExchange.git
# %cd ComputeExchange
# !pip install -q transformers trl datasets torch accelerate matplotlib
# !pip install -q -e ./packages/shared-types
# !pip install -q -e ./openenv/compute_market_env

# %%
# Cell 2: Run training (episodes, reward curves, trajectory export, TRL)
# %run scripts/train_colab.py
